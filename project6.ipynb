# %% [markdown]
# #### MongoDB Code Lab

# %%
# %env HOST=mongodb+srv://cluster0.oostpcw.mongodb.net/sample_weatherdata
# %env USER=tonyjqi
# %env PW=9qAJpagY83EymCQT
# Out:
# env: HOST=mongodb+srv://cluster0.oostpcw.mongodb.net/sample_weatherdata
# env: USER=tonyjqi
# env: PW=9qAJpagY83EymCQT

# %%
CONNECT="/usr/bin/mongosh $HOST -u $USER -p $PW"

# %%
# !{CONNECT}
# Out:
# Current Mongosh Log ID:	653b09663cab1b3493caf77d
# Connecting to:		mongodb+srv://<credentials>@cluster0.oostpcw.mongodb.net/sample_weatherdata?appName=mongosh+2.0.2
# Using MongoDB:		6.0.11
# Using Mongosh:		2.0.2
#
# For mongosh info see: https://docs.mongodb.com/mongodb-shell/
#
#  Atlas atlas-2oveo8-shard-0 [primary] sample_weatherdata>
# (To exit, press Ctrl+C again or Ctrl+D or type .exit)
# Atlas atlas-2oveo8-shard-0 [primary] sample_weatherdata>

# %%
# !{CONNECT} --eval "show collections"
# Out:
# Current Mongosh Log ID:	653acbe4fd04a5e9872defff
# Connecting to:		mongodb+srv://<credentials>@cluster0.oostpcw.mongodb.net/sample_weatherdata?appName=mongosh+2.0.2
# Using MongoDB:		6.0.11
# Using Mongosh:		2.0.2
#
# For mongosh info see: https://docs.mongodb.com/mongodb-shell/
#
#  data

# %%
# !{CONNECT} --eval "db.data.findOne()"
# Out:
# Current Mongosh Log ID:	6536a93534708b145fd5899b
# Connecting to:		mongodb+srv://<credentials>@cluster0.oostpcw.mongodb.net/sample_weatherdata?appName=mongosh+2.0.2
# Using MongoDB:		6.0.11
# Using Mongosh:		2.0.2
#
# For mongosh info see: https://docs.mongodb.com/mongodb-shell/
#
#  {
#   _id: ObjectId("5553a998e4b02cf7151190cb"),
#   st: 'x+43400-065600',
#   ts: ISODate("1984-03-05T18:00:00.000Z"),
#   position: { type: 'Point', coordinates: [ -65.6, 43.4 ] },
#   elevation: 9999,
#   callLetters: 'CG26',
#   qualityControlProcess: 'V020',
#   dataSource: '4',
#   type: 'FM-13',
#   airTemperature: { value: 999.9, quality: '9' },
#   dewPoint: { value: 999.9, quality: '9' },
#   pressure: { value: 9999.9, quality: '9' },
#   wind: {
#     direction: { angle: 270, quality: '1' },
#     type: 'N',
#     speed: { rate: 7.7, quality: '1' }
#   },
#   visibility: {
#     distance: { value: 10000, quality: '1' },
#     variability: { value: 'N', quality: '9' }
#   },
# ...

# %% [markdown]
# #### Begin project 6 work.

# %%
# !{CONNECT} -f /home/jupyter/snippets_10_20/snippets/project6_queries.js
# Out:
# Current Mongosh Log ID:	653ae0a1fa853e4b8d7e85d0
# Connecting to:		mongodb+srv://<credentials>@cluster0.oostpcw.mongodb.net/sample_weatherdata?appName=mongosh+2.0.2
# Using MongoDB:		6.0.11
# Using Mongosh:		2.0.2
#
# For mongosh info see: https://docs.mongodb.com/mongodb-shell/
#
#  Loading file: /home/jupyter/snippets_10_20/snippets/project6_queries.js
# ****************************************************************
# 1) Finds documents with qualityControlProcess = 'V020' and callLetters = 'PHRB' and returns their id, elevation, and type. The found documents are returned in order of id.
# [
#   {
#     _id: ObjectId("5553a998e4b02cf7151190d3"),
#     elevation: 9999,
#     type: 'FM-13'
#   },
#   {
#     _id: ObjectId("5553a998e4b02cf71511940d"),
#     elevation: 9999,
#     type: 'FM-13'
#   },
#   {
#     _id: ObjectId("5553a998e4b02cf71511a023"),
#     elevation: 9999,
#     type: 'FM-13'
#   }
# ]
# ****************************************************************
# ...

# %% [markdown]
# #### Begin extra credit work

# %%
# !{CONNECT} -f /home/jupyter/snippets_10_20/snippets/exam1_extra_credit.js
# Out:
# Current Mongosh Log ID:	653b0a7cbb4c8596085fed97
# Connecting to:		mongodb+srv://<credentials>@cluster0.oostpcw.mongodb.net/sample_weatherdata?appName=mongosh+2.0.2
# Using MongoDB:		6.0.11
# Using Mongosh:		2.0.2
#
# For mongosh info see: https://docs.mongodb.com/mongodb-shell/
#
#  Loading file: /home/jupyter/snippets_10_20/snippets/exam1_extra_credit.js
# ****************************************************************
# 1) Insert one document with position.elevation 9999, position.callLetters 'NK3S', st: x+43500-038420, dewPoint value 999.9, quality '7', airTemperature value 240.5, quality'6', pressure value 9999.9 quality '5'.
# {
#   acknowledged: true,
#   insertedId: ObjectId("653b0a7ebb4c8596085fed98")
# }
# ****************************************************************
# ...
